# %%
import numpy as np
import pandas as pd
import seaborn as sb
sb.set()
import matplotlib.pyplot as plt
reg_data = pd.read_excel('WHR2018Chapter2OnlineData.xls',sheet_name = 'SupportingFactors')
data=pd.read_excel('WHR2018Chapter2OnlineData.xls',sheet_name = 'Table2.1')

# %%
region = pd.DataFrame(reg_data[["country","Region indicator"]])
region.head(100)
# Out:
#                      country                    Region indicator
# 0                Afghanistan                          South Asia
# 1                    Albania          Central and Eastern Europe
# 2                    Algeria        Middle East and North Africa
# 3                     Angola                  Sub-Saharan Africa
# 4                  Argentina         Latin America and Caribbean
# 5                    Armenia  Commonwealth of Independent States
# 6                  Australia               North America and ANZ
# 7                    Austria                      Western Europe
# 8                 Azerbaijan  Commonwealth of Independent States
# 9                    Bahrain        Middle East and North Africa
# 10                Bangladesh                          South Asia
# 11                   Belarus  Commonwealth of Independent States
# 12                   Belgium                      Western Europe
# ...

# %%
data_M = data.merge(region, on='country', how='left')
col = list(data_M)
col.insert(1,col.pop(col.index('Region indicator')))
data_M = data_Merged.loc[:,col]
data_Merged = data_M.dropna()
data_Merged.head(100)
# Out:
#                 country                    Region indicator  year  \
# 14              Albania          Central and Eastern Europe  2012
# 33            Argentina         Latin America and Caribbean  2009
# 34            Argentina         Latin America and Caribbean  2010
# 35            Argentina         Latin America and Caribbean  2011
# 36            Argentina         Latin America and Caribbean  2012
# 37            Argentina         Latin America and Caribbean  2013
# 38            Argentina         Latin America and Caribbean  2014
# 45              Armenia  Commonwealth of Independent States  2009
# 46              Armenia  Commonwealth of Independent States  2010
# 47              Armenia  Commonwealth of Independent States  2011
# 48              Armenia  Commonwealth of Independent States  2012
# 49              Armenia  Commonwealth of Independent States  2013
# 50              Armenia  Commonwealth of Independent States  2014
# ...

# %%
data_Merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382 entries, 14 to 1555
# Data columns (total 20 columns):
# country                                                     382 non-null object
# Region indicator                                            382 non-null object
# year                                                        382 non-null int64
# Life Ladder                                                 382 non-null float64
# Log GDP per capita                                          382 non-null float64
# Social support                                              382 non-null float64
# Healthy life expectancy at birth                            382 non-null float64
# Freedom to make life choices                                382 non-null float64
# Generosity                                                  382 non-null float64
# Perceptions of corruption                                   382 non-null float64
# ...

# %%
print("number of regions:",len(data_Merged["Region indicator"].unique()))
print(data_Merged["Region indicator"].unique())
data_Merged["Region indicator"].value_counts()
# Out:
# number of regions: 10
# ['Central and Eastern Europe' 'Latin America and Caribbean'
#  'Commonwealth of Independent States' 'North America and ANZ'
#  'Western Europe' 'South Asia' 'Sub-Saharan Africa'
#  'Middle East and North Africa' 'Southeast Asia' 'East Asia']
# Latin America and Caribbean           99
# Western Europe                        92
# Central and Eastern Europe            64
# Commonwealth of Independent States    59
# Sub-Saharan Africa                    24
# Middle East and North Africa          14
# Southeast Asia                        13
# South Asia                             8
# North America and ANZ                  5
# East Asia                              4
# Name: Region indicator, dtype: int64

# %%
f, axes = plt.subplots(1, 1, figsize=(32, 5))
sb.countplot(data_Merged["Region indicator"])

# %%
SSA = pd.DataFrame(data[data_Merged["Region indicator"] == "Sub-Saharan Africa"])
LAC = pd.DataFrame(data[data_Merged["Region indicator"] == "Latin America and Caribbean"])
WE = pd.DataFrame(data[data_Merged["Region indicator"] == "Western Europe"])
MENA = pd.DataFrame(data[data_Merged["Region indicator"] == "Middle East and North Africa"])
CEE = pd.DataFrame(data[data_Merged["Region indicator"] == "Central and Eastern Europe"])
CIS = pd.DataFrame(data[data_Merged["Region indicator"] == "Commonwealth of Independent States"])
SEA = pd.DataFrame(data[data_Merged["Region indicator"] == "Southeast Asia"])
SA = pd.DataFrame(data[data_Merged["Region indicator"] == "South Asia"])
EA = pd.DataFrame(data[data_Merged["Region indicator"] == "East Asia"])
NAA = pd.DataFrame(data[data_Merged["Region indicator"] == "North America and ANZ"])
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-22-91df74e7e3c8> in <module>
# ----> 1 SSA = pd.DataFrame(data[data_Merged["Region indicator"] == "Sub-Saharan Africa"])
#       2 LAC = pd.DataFrame(data[data_Merged["Region indicator"] == "Latin America and Caribbean"])
#       3 WE = pd.DataFrame(data[data_Merged["Region indicator"] == "Western Europe"])
#       4 MENA = pd.DataFrame(data[data_Merged["Region indicator"] == "Middle East and North Africa"])
#       5 CEE = pd.DataFrame(data[data_Merged["Region indicator"] == "Central and Eastern Europe"])
#
# E:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
SSA.head(100)
# Out:
#                  country  year  Life Ladder  Log GDP per capita  \
# 26                Angola  2011     5.589001            8.684613
# 27                Angola  2012     4.360250            8.699287
# 28                Angola  2013     3.937107            8.729884
# 29                Angola  2014     3.794838            8.741957
# 133                Benin  2006     3.329802            7.469060
# 134                Benin  2008     3.667140            7.518200
# 135                Benin  2011     3.870280            7.507083
# 136                Benin  2012     3.193469            7.526094
# 137                Benin  2013     3.479413            7.567654
# 138                Benin  2014     3.347419            7.601467
# 139                Benin  2015     3.624664            7.594465
# 140                Benin  2016     4.007358            7.605871
# 141                Benin  2017     4.853181            7.632503
# 167             Botswana  2006     4.739367            9.422458
# ...
