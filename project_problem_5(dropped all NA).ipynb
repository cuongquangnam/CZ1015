# %%
import numpy as np
import pandas as pd
import seaborn as sb
sb.set()
import matplotlib.pyplot as plt
data = pd.read_excel('WHR2018Chapter2OnlineData.xls',sheet_name = 'Table2.1').dropna()
data.head()
# Out:
#       country  year  Life Ladder  Log GDP per capita  Social support  \
# 14    Albania  2012     5.510124            9.246649        0.784502
# 33  Argentina  2009     6.424133            9.750825        0.918693
# 34  Argentina  2010     6.441067            9.836924        0.926799
# 35  Argentina  2011     6.775805            9.884781        0.889073
# 36  Argentina  2012     6.468387            9.863960        0.901776
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 14                         68.028885                      0.601512
# 33                         66.410309                      0.636646
# 34                         66.552177                      0.730258
# 35                         66.694588                      0.815802
# 36                         66.836693                      0.747498
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382 entries, 14 to 1555
# Data columns (total 19 columns):
# country                                                     382 non-null object
# year                                                        382 non-null int64
# Life Ladder                                                 382 non-null float64
# Log GDP per capita                                          382 non-null float64
# Social support                                              382 non-null float64
# Healthy life expectancy at birth                            382 non-null float64
# Freedom to make life choices                                382 non-null float64
# Generosity                                                  382 non-null float64
# Perceptions of corruption                                   382 non-null float64
# Positive affect                                             382 non-null float64
# ...

# %%
LL = pd.DataFrame(data['Life Ladder'])
GDP=pd.DataFrame(data['Log GDP per capita'])
SS=pd.DataFrame(data['Social support'])
LE=pd.DataFrame(data['Healthy life expectancy at birth'])
F=pd.DataFrame(data['Freedom to make life choices'])
G=pd.DataFrame(data['Generosity'])
CO=pd.DataFrame(data['Perceptions of corruption'])
PA=pd.DataFrame(data['Positive affect'])
NA=pd.DataFrame(data['Negative affect'])
CNG=pd.DataFrame(data['Confidence in national government'])
DQ=pd.DataFrame(data['Democratic Quality'])
DeQ=pd.DataFrame(data['Delivery Quality'])
SD=pd.DataFrame(data['Standard deviation of ladder by country-year'])
SD_M=pd.DataFrame(data['Standard deviation/Mean of ladder by country-year'])
GINI=pd.DataFrame(data['GINI index (World Bank estimate)'])
GINI_ave=pd.DataFrame(data['GINI index (World Bank estimate), average 2000-15'])
gini_hi=pd.DataFrame(data['gini of household income reported in Gallup, by wp5-year'])

# %%
overall = pd.concat([LL, GDP, SS, LE, F, G, CO, PA, NA, CNG, DQ, DeQ, SD, SD_M, GINI, GINI_ave, gini_hi], axis = 1, join_axes = [LL.index])
f, axes = plt.subplots(1, 1, figsize=(12, 8))
sb.heatmap(overall.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")

# %%
sb.pairplot(data = overall)
# Out:
# E:\anaconda\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '

# %%
overall.head()
# Out:
#     Life Ladder  Log GDP per capita  Social support  \
# 14     5.510124            9.246649        0.784502
# 33     6.424133            9.750825        0.918693
# 34     6.441067            9.836924        0.926799
# 35     6.775805            9.884781        0.889073
# 36     6.468387            9.863960        0.901776
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 14                         68.028885                      0.601512
# 33                         66.410309                      0.636646
# 34                         66.552177                      0.730258
# 35                         66.694588                      0.815802
# 36                         66.836693                      0.747498
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 14   -0.174559                   0.847675         0.606636         0.271393
# 33   -0.129523                   0.884742         0.863786         0.236901
# ...

# %%
y = LL
X = overall.drop(['Life Ladder'],axis = 1)

# %%
X.head(100)
# Out:
#      Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 14             9.246649        0.784502                         68.028885
# 33             9.750825        0.918693                         66.410309
# 34             9.836924        0.926799                         66.552177
# 35             9.884781        0.889073                         66.694588
# 36             9.863960        0.901776                         66.836693
# 37             9.877256        0.909874                         66.977570
# 38             9.841482        0.917870                         67.118126
# 45             8.784616        0.680007                         63.658070
# 46             8.810287        0.660342                         63.841919
# 47             8.856818        0.705108                         64.048599
# 48             8.924142        0.676446                         64.258392
# 49             8.952597        0.723260                         64.455490
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

print("X_Train Set :", X_train.shape)
print("X_Test Set  :", X_test.shape)
print("y_Train Set :", y_train.shape)
print("y_Test Set  :", y_test.shape)
# Out:
# X_Train Set : (286, 16)
# X_Test Set  : (96, 16)
# y_Train Set : (286, 1)
# y_Test Set  : (96, 1)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, y_train)
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [5.30101557]
# Coefficients of Regression 	: a =  [[ 8.72694201e-02 -3.94770733e-01  8.15776321e-04  4.13286654e-01
#    2.14671969e-01 -6.98218465e-01  5.90460166e-01  1.93953809e-01
#   -2.34321621e-01  6.86746917e-02 -7.61301518e-03  2.02451440e+00
#   -1.19937111e+01  9.07352158e-01 -1.06984987e+00  2.92813346e-01]]
#                                            Predictors  Coefficients
# 0                                  Log GDP per capita      0.087269
# 1                                      Social support     -0.394771
# 2                    Healthy life expectancy at birth      0.000816
# 3                        Freedom to make life choices      0.413287
# 4                                          Generosity      0.214672
# 5                           Perceptions of corruption     -0.698218
# 6                                     Positive affect      0.590460
# 7                                     Negative affect      0.193954
# ...

# %%
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.9643962523741613
# Mean Squared Error (MSE) 	: 0.040378231492189144
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.9434475251612205
# Mean Squared Error (MSE) 	: 0.04826356360830403

# %%
y = LL
X = pd.concat([GDP, SS, LE, F, PA, DQ, DeQ, SD_M], axis = 1, join_axes = [GDP.index])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

print("X_Train Set :", X_train.shape)
print("X_Test Set  :", X_test.shape)
print("y_Train Set :", y_train.shape)
print("y_Test Set  :", y_test.shape)

from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, y_train)
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])

y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

from sklearn.metrics import mean_squared_error
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# X_Train Set : (343, 8)
# X_Test Set  : (39, 8)
# y_Train Set : (343, 1)
# y_Test Set  : (39, 1)
# Intercept of Regression 	: b =  [1.08457295]
# Coefficients of Regression 	: a =  [[ 2.22030282e-01 -2.46016100e-03  3.37058776e-02  2.82698968e-01
#    2.86001437e+00  7.12305339e-02 -8.61083994e-02 -5.17304829e+00]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8495182869090164
# Mean Squared Error (MSE) 	: 0.16059356595833438
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8212764633586632
# Mean Squared Error (MSE) 	: 0.18518470111885474
